# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
# sentences

sent = ['the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meaning of words',
        'your video are good']

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your video are good']

# %%
## define the vocabulary size
voc_size = 10000

# %%
## one hot representation
one_hot_repr = [one_hot(words,voc_size) for words in sent]
one_hot_repr
# Out:
# [[3703, 9450, 5976, 8802],
#  [3703, 9450, 5976, 2952],
#  [3703, 5435, 5976, 2809],
#  [2920, 8550, 5864, 2540, 6154],
#  [2920, 8550, 5864, 2540, 5427],
#  [3459, 3703, 2733, 5976, 64],
#  [7330, 3157, 5634, 2540]]

# %%
## word embbeding representetion

from tensorflow.keras.layers import Embedding
# from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_len = 8
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_len)
print(embedded_docs)
# Out:
# [[   0    0    0    0 3703 9450 5976 8802]
#  [   0    0    0    0 3703 9450 5976 2952]
#  [   0    0    0    0 3703 5435 5976 2809]
#  [   0    0    0 2920 8550 5864 2540 6154]
#  [   0    0    0 2920 8550 5864 2540 5427]
#  [   0    0    0 3459 3703 2733 5976   64]
#  [   0    0    0    0 7330 3157 5634 2540]]

# %%
## feature representation
dim = 10

# %%
model=Sequential()
model.add(Embedding(input_dim=voc_size, output_dim=dim, input_shape=(sent_len,)))
model.compile(optimizer='adam',loss='mse')
# Out:
# d:\gen-ai\python basic\python_basic\Lib\site-packages\keras\src\layers\core\embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# array([[[ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [-0.00554192,  0.01171758,  0.0010704 , -0.04581686,
#           0.02337286,  0.00160351, -0.03604358,  0.03819752,
#           0.00693319,  0.02243047],
#         [ 0.01861687, -0.04071094, -0.04274304, -0.01892561,
#          -0.03813845, -0.02722983, -0.04969553, -0.01334268,
#          -0.01210022, -0.04090964],
#         [ 0.01676795,  0.04652381, -0.01632308,  0.01714046,
#          -0.01121478,  0.03090615, -0.0283832 ,  0.01663252,
#           0.04553682,  0.01577273],
#         [ 0.02516853,  0.00983799, -0.03306778,  0.02028352,
#          -0.02717043,  0.02006972, -0.02057325,  0.01094872,
#           0.01108158, -0.03496004]],
#
#        [[ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [-0.00554192,  0.01171758,  0.0010704 , -0.04581686,
#           0.02337286,  0.00160351, -0.03604358,  0.03819752,
#           0.00693319,  0.02243047],
#         [ 0.01861687, -0.04071094, -0.04274304, -0.01892561,
#          -0.03813845, -0.02722983, -0.04969553, -0.01334268,
#          -0.01210022, -0.04090964],
#         [ 0.01676795,  0.04652381, -0.01632308,  0.01714046,
#          -0.01121478,  0.03090615, -0.0283832 ,  0.01663252,
#           0.04553682,  0.01577273],
#         [ 0.02602756,  0.03255631, -0.03518932,  0.02418024,
#          -0.00085794,  0.03407785, -0.03020589, -0.04129237,
#           0.03374473,  0.0134095 ]],
#
#        [[ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [-0.00554192,  0.01171758,  0.0010704 , -0.04581686,
#           0.02337286,  0.00160351, -0.03604358,  0.03819752,
#           0.00693319,  0.02243047],
#         [ 0.01535702, -0.00892837, -0.01437201,  0.00932546,
#          -0.01258469, -0.04442985,  0.04752013,  0.00094327,
#          -0.01604299,  0.01008718],
#         [ 0.01676795,  0.04652381, -0.01632308,  0.01714046,
#          -0.01121478,  0.03090615, -0.0283832 ,  0.01663252,
#           0.04553682,  0.01577273],
#         [-0.02945589,  0.0310434 ,  0.03034481,  0.02057353,
#           0.01956872,  0.03068227, -0.00165193,  0.02609133,
#          -0.02927173,  0.02071697]],
#
#        [[ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [-0.01550047, -0.03693147, -0.02129263,  0.03489352,
#           0.03516001, -0.00813168,  0.01878395,  0.01000633,
#          -0.01014853,  0.00044509],
#         [-0.0018657 , -0.01276448, -0.04772537, -0.02551267,
#          -0.02055584,  0.02128584,  0.00127735,  0.04508145,
#           0.03406013, -0.0322203 ],
#         [-0.03308655, -0.02715718, -0.03518088, -0.01517294,
#           0.03706389, -0.00792775,  0.03438536, -0.02042145,
#          -0.02355838,  0.01156985],
#         [ 0.02984787,  0.04119824,  0.0459297 , -0.02423892,
#           0.00977775,  0.03921339,  0.00689633,  0.02340368,
#           0.04267946,  0.02579662],
#         [ 0.01973536,  0.02687268,  0.04061905, -0.0280826 ,
#          -0.01486379,  0.03684619,  0.04361368,  0.02748689,
#           0.01070362, -0.03113681]],
#
#        [[ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [-0.01550047, -0.03693147, -0.02129263,  0.03489352,
#           0.03516001, -0.00813168,  0.01878395,  0.01000633,
#          -0.01014853,  0.00044509],
#         [-0.0018657 , -0.01276448, -0.04772537, -0.02551267,
#          -0.02055584,  0.02128584,  0.00127735,  0.04508145,
#           0.03406013, -0.0322203 ],
#         [-0.03308655, -0.02715718, -0.03518088, -0.01517294,
#           0.03706389, -0.00792775,  0.03438536, -0.02042145,
#          -0.02355838,  0.01156985],
#         [ 0.02984787,  0.04119824,  0.0459297 , -0.02423892,
#           0.00977775,  0.03921339,  0.00689633,  0.02340368,
#           0.04267946,  0.02579662],
#         [ 0.04844302,  0.04730587, -0.01816931, -0.01407854,
#           0.03666724, -0.01605947,  0.03909308,  0.03657899,
#           0.03642282,  0.03157273]],
#
#        [[ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [-0.01917808, -0.02336017,  0.04008862, -0.03711037,
#          -0.04709458,  0.02441842,  0.01466074,  0.02056133,
#          -0.03106349,  0.0411363 ],
#         [-0.00554192,  0.01171758,  0.0010704 , -0.04581686,
#           0.02337286,  0.00160351, -0.03604358,  0.03819752,
#           0.00693319,  0.02243047],
#         [ 0.03227882, -0.00954089, -0.03953258, -0.02784373,
#          -0.02479153,  0.04566277,  0.00079386, -0.00207795,
#           0.02760809,  0.02151776],
#         [ 0.01676795,  0.04652381, -0.01632308,  0.01714046,
#          -0.01121478,  0.03090615, -0.0283832 ,  0.01663252,
#           0.04553682,  0.01577273],
#         [ 0.04180915, -0.02984111, -0.01734277, -0.02077242,
#          -0.01598221, -0.04889799, -0.0455881 , -0.02549907,
#          -0.02819353,  0.0251025 ]],
#
#        [[ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,
#           0.02271143,  0.040554  ,  0.04936789, -0.00329766,
#           0.04783839, -0.02468538],
#         [ 0.03182614,  0.03204409,  0.02255702,  0.00083207,
#          -0.04857926,  0.04399555, -0.04495291,  0.0119337 ,
#          -0.02413952, -0.01028709],
#         [-0.04486639, -0.00105391,  0.00923537, -0.0418045 ,
#           0.01393363,  0.00094641,  0.02514922, -0.00426663,
#          -0.03710622, -0.0273149 ],
#         [ 0.04922705, -0.01514726, -0.00029195, -0.03292414,
#           0.04021854, -0.00064198, -0.02020898,  0.00065678,
#          -0.0025448 , -0.03982078],
#         [ 0.02984787,  0.04119824,  0.0459297 , -0.02423892,
#           0.00977775,  0.03921339,  0.00689633,  0.02340368,
#           0.04267946,  0.02579662]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 3703, 9450, 5976, 8802], dtype=int32)

# %%
model.predict(embedded_docs)[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# array([[ 0.04377786, -0.00115523,  0.04186858, -0.04550324,  0.02271143,
#          0.040554  ,  0.04936789, -0.00329766,  0.04783839, -0.02468538],
#        [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,  0.02271143,
#          0.040554  ,  0.04936789, -0.00329766,  0.04783839, -0.02468538],
#        [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,  0.02271143,
#          0.040554  ,  0.04936789, -0.00329766,  0.04783839, -0.02468538],
#        [ 0.04377786, -0.00115523,  0.04186858, -0.04550324,  0.02271143,
#          0.040554  ,  0.04936789, -0.00329766,  0.04783839, -0.02468538],
#        [-0.00554192,  0.01171758,  0.0010704 , -0.04581686,  0.02337286,
#          0.00160351, -0.03604358,  0.03819752,  0.00693319,  0.02243047],
#        [ 0.01861687, -0.04071094, -0.04274304, -0.01892561, -0.03813845,
#         -0.02722983, -0.04969553, -0.01334268, -0.01210022, -0.04090964],
#        [ 0.01676795,  0.04652381, -0.01632308,  0.01714046, -0.01121478,
#          0.03090615, -0.0283832 ,  0.01663252,  0.04553682,  0.01577273],
#        [ 0.02516853,  0.00983799, -0.03306778,  0.02028352, -0.02717043,
#          0.02006972, -0.02057325,  0.01094872,  0.01108158, -0.03496004]],
#       dtype=float32)
